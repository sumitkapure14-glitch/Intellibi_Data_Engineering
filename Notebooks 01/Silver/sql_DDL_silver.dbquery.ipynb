-- %%
CREATE OR REPLACE TABLE sumit_catlog.sumit_silver.cleanedMonthly_sales
(
    sale_id integer,product string,category string,
    quantity integer,price double,
    sale_date date,region string, 
    ingest_ts timestamp 
);

describe sumit_catlog.sumit_silver.cleanedMonthly_sales;
-- describe history sumit_catlog.sumit_silver.cleanedMonthly_sales;
select * from sumit_catlog.sumit_silver.cleanedMonthly_sales;

-- drop table sumit_catlog.sumit_bronze01.dfMonthly_sales;

--drop table sumit_catlog.sumit_silver01.dfMonthly_sales;
TRUNCATE TABLE sumit_catlog.sumit_silver.cleanedMonthly_sales;
