-- %%
CREATE OR REPLACE TABLE sumit_catlog.sumit_bronze01.rawMonthly_sales
(
    sale_id integer,product string,category string,
    quantity integer,price double,
    sale_date date,region string, 
    ingest_ts timestamp 
);

describe sumit_catlog.sumit_bronze01.rawMonthly_sales;
describe history sumit_catlog.sumit_bronze01.rawMonthly_sales;
select * from sumit_catlog.sumit_bronze01.rawMonthly_sales;

-- drop table sumit_catlog.sumit_bronze01.dfMonthly_sales;
