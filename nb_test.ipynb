# %%
# %sql
truncate table sumit_catlog.sumit_bronze01.dfMonthly_sales;
truncate table sumit_catlog.sumit_silver01.dfMonthly_sales;
truncate table sumit_catlog.sumit_gold01.dfMonthly_sales;

# %%
# %sql
-- truncate table sumit_catlog.sumit_gold01.dfMonthly_sales;
select count(*) from sumit_catlog.sumit_gold01.dfMonthly_sales;

# %%
# %sql
-- truncate table sumit_catlog.sumit_silver01.dfMonthly_sales;
select count(*) from sumit_catlog.sumit_silver01.dfMonthly_sales;

# %%
# %sql
-- truncate table sumit_catlog.sumit_bronze01.dfMonthly_sales;
select count(*) from sumit_catlog.sumit_bronze01.dfMonthly_sales;
